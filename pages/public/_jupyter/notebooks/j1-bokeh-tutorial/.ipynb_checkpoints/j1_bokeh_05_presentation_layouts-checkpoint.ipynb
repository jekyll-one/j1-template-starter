# %% [markdown]
# ## 5. Presentation and Layout
#
# In the previous chapters we started to learn how to create single plots using differnet kinds of data. But we often want to plot more than one thing. Bokeh plots can be individually embedded in HTML documents, but it's often easier to
# combine multiple plots in one of Bokeh's built-in layouts. We will learn how to do that in this chapter.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

import numpy as np

# %%
#nbi:hide_out
# Make all outputs INLINE for default (why a hell this is needed !!!)
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# The cell below defines a few data variables we will use in examples.

# %%
x = list(range(11))
y0, y1, y2 = x, [10-i for i in x], [abs(i-5) for i in x]

# %% [markdown]
# ### Rows and Columns
# The `bokeh.layouts` modules provides the ``row`` and ``column`` functions to arrange plot objects in vertical or horizontal layouts. Below is an example of three plots arranged in a row.

# %%
from bokeh.layouts import row

# create a new plot
s1 = figure(
    width=250,
    plot_height=250
)
s1.circle(
    x,
    y0, 
    size=10,
    color="navy",
    alpha=0.5
)

# create a 2nd one
s2 = figure(
    width=250,
    plot_height=250
)
s2.triangle(
    x,
    y1,
    size=10,
    color="firebrick",
    alpha=0.5
)

# create the 3rd one
s3 = figure(
    width=250,
    plot_height=250
)
s3.square(
    x,
    y2,
    size=10,
    color="olive",
    alpha=0.5
)

# show the results in a row
show(
    row(s1, s2, s3)
)
# Out:
#   <div class="bk-root" id="0efc0463-8d97-4e66-b8c9-35a25fb6c72e" data-root-id="1114"></div>

# %% [markdown]
# ### Grid plots
#
# Bokeh also provides a `gridplot` layout in `bokeh.layouts` for arranging plots in a grid, as show in the example below.

# %%
from bokeh.layouts import gridplot

# create a new plot
s1 = figure(
    width=250,
    plot_height=250
)
s1.circle(
    x,
    y0,
    size=10,
    color="navy",
    alpha=0.5
)

# # create a 2nd one
s2 = figure(
    width=250,
    plot_height=250
)
s2.triangle(
    x,
    y1,
    size=10,
    color="firebrick",
    alpha=0.5
)

# create the 3rd one
s3 = figure(
    width=250,
    plot_height=250
)
s3.square(
    x,
    y2,
    size=10,
    color="olive",
    alpha=0.5
)

# put all the plots in a gridplot
p = gridplot(
    [
        [s1, s2],
        [s3, None]
    ],
    toolbar_location=None
)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="e814ddc9-a4d2-4efa-a629-aeb5b5cec2e9" data-root-id="1460"></div>
